# %%
# !pip install langchain
# !pip install openai
# !pip install tiktoken
# !pip install youtube-transcript-api

# %%
### import the libraries
from langchain.document_loaders import YoutubeLoader
from langchain.llms import OpenAI
from langchain.chains.summarize import load_summarize_chain
import os
os.environ["OPENAI_API_KEY"] = '<your token>'

# %%
# !pip install pytube

# %%
#load youtube and create transcript
loader = YoutubeLoader.from_youtube_url("https://www.youtube.com/watch?v=H8eP99neOVs&ab_channel=Erin%27Folletto%27Casali", add_video_info=True)
result = loader.load()
print(f"Found Video from {result[0].metadata['author']} that is {result[0].metadata['length']} seconds long!")
# Out:
# Found Video from Erin 'Folletto' Casali that is 186 seconds long!

# %%
result, type(result)
# Out:
# ([Document(page_content="(Audience) What about OpenDoc? What about OpenDoc? Yeah What about it? It's dead right? It's dead right? Yeah Well... you know... let me say something as this is sort of generic. I know some of you spent a lot of time working on stuff that we put a bullet in the head of. I apologize. I feel your pain but Apple suffered for several years from lousy engineering management I have to say it and there were people\nthat were going off in eighteen different directions doing arguably\ninteresting things in each one of them. Good engineers. Lousy management. And what happened was you look at the farm that's been created with all these different\nanimals going in different directions and it doesn't add up the total is less\nthan the sum of the parts. And so we had to decide what are the fundamental\ndirections we're going in and what makes sense and what doesn't and there were a\nbunch of things that didn't and microcosmically they might have made\nsense macrocosmicall
# ...

# %%
##LLM setup
os.environ["OPENAI_API_KEY"] = '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'
llm = OpenAI(temperature=0.75)
chain = load_summarize_chain(llm=llm, chain_type='stuff', verbose=True)

# %%
chain.run(result)
# Out:
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "(Audience) What about OpenDoc? What about OpenDoc? Yeah What about it? It's dead right? It's dead right? Yeah Well... you know... let me say something as this is sort of generic. I know some of you spent a lot of time working on stuff that we put a bullet in the head of. I apologize. I feel your pain but Apple suffered for several years from lousy engineering management I have to say it and there were people
# that were going off in eighteen different directions doing arguably
# interesting things in each one of them. Good engineers. Lousy management. And what happened was you look at the farm that's been created with all these different
# animals going in different directions and it doesn't add up the total is less
# than the sum of the parts. And so we had to decide what are the fundamental
# ...

# %%
### long youtube videos
loader_long = YoutubeLoader.from_youtube_url('https://www.youtube.com/watch?v=5QBkn42PSxk&ab_channel=CNBCTelevision', add_video_info=True)
result_long = loader_long.load()
print(f"Found Video from {result_long[0].metadata['author']} that is {result_long[0].metadata['length']} seconds long!")
# Out:
# Found Video from CNBC Television that is 9113 seconds long!

# %%
print(result_long)
# Out:
# [Document(page_content="sales are terrific out there so you're my kind of crowd I've been getting reports we're breaking all kinds of Records and we're going to start off uh with question number 26. which goes to station two I one and Charlize my name is James from Malaysia given the reason challenge faced by the major U.S Bank what is your overall outlook on the banking industry how do you assess the risk and the opportunity in this section well anticipating a few questions on banks I decided we should start using Bank language here to describe [Music] Charlie [Applause] the the situation in banking is is very similar to what it's always been in banking that that fear is contagious always and historically sometimes the fear was justified and sometimes it wasn't my dad lost his job in 1931 because of a bank run and they had a bank run on the State Banks and uh the head of the Omaha National Bank said well we're a national bank and they didn't have a run on the National Banks and of c
# ...

# %%
###Seting up LLM
llm = OpenAI(temperature=0.7)
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_documents(result_long)
len(texts)
# Out:
# 145

# %%
texts[0]
# Out:
# Document(page_content="sales are terrific out there so you're my kind of crowd I've been getting reports we're breaking all kinds of Records and we're going to start off uh with question number 26. which goes to station two I one and Charlize my name is James from Malaysia given the reason challenge faced by the major U.S Bank what is your overall outlook on the banking industry how do you assess the risk and the opportunity in this section well anticipating a few questions on banks I decided we should start using Bank language here to describe [Music] Charlie [Applause] the the situation in banking is is very similar to what it's always been in banking that that fear is contagious always and historically sometimes the fear was justified and sometimes it wasn't my dad lost his job in 1931 because of a bank run and they had a bank run on the State Banks and uh the head of the Omaha National Bank said well we're a national bank and they didn't have a run on the National Banks and of co
# ...

# %%
texts[1]
# Out:
# Document(page_content="and they had a bank run on the State Banks and uh the head of the Omaha National Bank said well we're a national bank and they didn't have a run on the National Banks and of course they both face the same problem so it it used to be that if you saw people lining up at a bank the proper response was to get into the line and uh you'll always leave it and the story is that Sydney weiberg of Goldman Sachs during one of the great Bank runs um back in 1907 or thereabouts had a job as a runner Goldman Sachs and asked us a boss if he could take the week off and your boss said sure not much is going on anyway so he got in line whether it's a Knickerbocker trust or wherever and as he got toward the front of the line he sold his place in line to somebody he didn't have an account of the bank but that was an asset and uh the banking system has changed so much over the years and we did something enormously sensible in my view uh when we set up the FDIC as many as 2 000 bank
# ...

# %%
chain_long = load_summarize_chain(llm=llm, chain_type='map_reduce', verbose=True)
chain_long.run(texts[:2])
# Out:
# > Entering new MapReduceDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# ...

# %%
#chain_long.run(texts)

# %%
#chain_long.run(texts[:2])

# %%
##LLM setup
llm = OpenAI(temperature=0.75)
chain = load_summarize_chain(llm=llm, chain_type='stuff', verbose=True)
content = texts[0]
chain.run([content])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-36cbfd3721fa> in <cell line: 4>()
#       2 llm = OpenAI(temperature=0.75)
#       3 chain = load_summarize_chain(llm=llm, chain_type='stuff', verbose=True)
# ----> 4 content = texts[0]
#       5 chain.run([content])
#
# NameError: name 'texts' is not defined

# %%
len(texts)
# Out:
# 145

# %%
import time
summary_out = []
time.sleep(10800)
for i in range(len(texts)):
  output = chain.run([texts[i]])
  summary_out.append(output)
  if i % 2 == 0 and i != 0:
    time.sleep(200)
# Out:
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# ...

# %%
summary_out
# Out:
# [' James from Malaysia answers an audience question regarding the risk and opportunity in the U.S banking industry. He compares the situation to what it has always been, noting that fear is contagious, and that sometimes the fear is justified and sometimes it is not. He also shares a personal story of his dad losing his job in 1931 due to a bank run.',
#  ' During a bank run on State Banks, the head of the Omaha National Bank stated that National Banks were not affected. Sydney Weiberg of Goldman Sachs during one of the bank runs of 1907 sold his place in line to someone without an account with the bank. To address banking problems, the FDIC was created and as a result, 2000 banks have failed.',
#  " The FDIC was set up to protect people's money in the banking system after 2000 banks failed in one year after World War One. Despite this, people are still worried about their deposits due to poor messaging from politicians, agencies, and the press.",
# ...

# %%
summary_out
# Out:
# []
